# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
iris_data = pd.read_csv("iris.csv", index_col="Id")
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
sns.histplot(iris_data["Sepal Width (cm)"])
# Out:
# <Axes: xlabel='Sepal Width (cm)', ylabel='Count'>

# %%
sns.kdeplot(data=iris_data["Sepal Width (cm)"], shade=True)
# Out:
# C:\Users\Jali\AppData\Local\Temp\ipykernel_12248\2751356414.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data["Sepal Width (cm)"], shade=True)
# <Axes: xlabel='Sepal Width (cm)', ylabel='Density'>

# %%
sns.set_style("darkgrid")
sns.kdeplot(data=iris_data, x="Petal Width (cm)", hue="Species", shade=True)

plt.title("Distribution of Petal Lengths, by Species")
# Out:
# C:\Users\Jali\AppData\Local\Temp\ipykernel_12248\4089527788.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data, x="Petal Width (cm)", hue="Species", shade=True)
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')
